# %%
import pandas as pd
import random
import pickle

# %%
# Define some example categories
trial_types = ['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4']
therapeutic_areas = ['Oncology', 'Cardiology', 'Neurology', 'Gastroenterology']
trial_phases = [1, 2, 3, 4]
inclusion_criteria = ['Yes', 'No']

# %%
# Generate synthetic data
data = []
for _ in range(1000):  # Generate 100 data points, you can adjust this number
    trial_type = random.choice(trial_types)
    therapeutic_area = random.choice(therapeutic_areas)
    trial_phase = random.choice(trial_phases)
    num_patients = random.randint(50, 300)
    inclusion = random.choice(inclusion_criteria)
    site_capacity = random.randint(50, 300)
    activation_time = random.randint(60, 300)  # Adjust range based on your use case
    
    data.append([trial_type, therapeutic_area, trial_phase, num_patients, inclusion, site_capacity, activation_time])

# %%
# Create a DataFrame
columns = ['Trial_Type', 'Therapeutic_Area', 'Trial_Phase', 'Number_of_Patients', 'Inclusion_Criteria', 'Site_Capacity', 'Activation_Time']
df = pd.DataFrame(data, columns=columns)

# Save it as a CSV file
df.to_csv('clinical_trial_data.csv', index=False)

# %%
df
# Out:
#     Trial_Type  Therapeutic_Area  Trial_Phase  Number_of_Patients  \
# 0      Phase 1          Oncology            3                 183
# 1      Phase 3         Neurology            4                 200
# 2      Phase 4          Oncology            1                 198
# 3      Phase 1  Gastroenterology            3                 269
# 4      Phase 4          Oncology            3                 194
# ..         ...               ...          ...                 ...
# 995    Phase 3         Neurology            1                 257
# 996    Phase 4          Oncology            4                 175
# 997    Phase 1  Gastroenterology            3                 156
# 998    Phase 4         Neurology            2                 246
# 999    Phase 4         Neurology            1                 108
#
#     Inclusion_Criteria  Site_Capacity  Activation_Time
# 0                   No            187               98
# 1                  Yes            184               63
# ...

# %%
# Save it as a CSV file
df.to_csv('clinical_trial_data.csv', index=False)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df['Trial_Type']= label_encoder.fit_transform(df['Trial_Type']) 
  
df['Trial_Type'].unique() 
df['Therapeutic_Area']= label_encoder.fit_transform(df['Therapeutic_Area']) 
  
df['Therapeutic_Area'].unique() 
df['Inclusion_Criteria']= label_encoder.fit_transform(df['Inclusion_Criteria']) 
  
df['Inclusion_Criteria'].unique()
# Out:
# array([0, 1])

# %%
df
# Out:
#      Trial_Type  Therapeutic_Area  Trial_Phase  Number_of_Patients  \
# 0             0                 3            3                 183
# 1             2                 2            4                 200
# 2             3                 3            1                 198
# 3             0                 1            3                 269
# 4             3                 3            3                 194
# ..          ...               ...          ...                 ...
# 995           2                 2            1                 257
# 996           3                 3            4                 175
# 997           0                 1            3                 156
# 998           3                 2            2                 246
# 999           3                 2            1                 108
#
#      Inclusion_Criteria  Site_Capacity  Activation_Time
# 0                     0            187               98
# ...

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler() 
#data_scaled = scaler.fit_transform(df)
#df = pd.DataFrame.from_records(data_scaled)

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

# In[7]:


from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)


# In[8]:


from sklearn.metrics import r2_score
Y_predict = lr_model.predict(X_test)
r2 = r2_score(y_test, Y_predict)
print('R2 score is {}'.format(r2))


# In[10]:


# Saving model to disk
pickle.dump(lr_model, open('lr_model.pkl','wb'))
# Out:
# R2 score is -0.02376187118147355

# %%
len(Y_predict)
# Out:
# 300

# %%
Y_predict
# Out:
# array([179.30066039, 186.1480746 , 179.46496676, 190.67725219,
#        180.42061168, 193.96361832, 181.40504418, 175.43577857,
#        182.33224562, 187.90013252, 185.5279588 , 189.97292941,
#        184.9505108 , 176.12435465, 186.28302534, 183.70838146,
#        178.54337773, 182.62482399, 182.78779445, 189.78372601,
#        179.81131488, 183.93353134, 183.96772766, 174.15353064,
#        187.77064377, 186.34988304, 185.72393466, 187.65593259,
#        180.20666154, 184.65855748, 188.39797974, 176.73732802,
#        187.36427941, 194.64201752, 182.07552345, 188.09307915,
#        188.22877668, 178.81495972, 185.74836577, 185.10543915,
#        178.32034567, 185.59708609, 180.79081271, 183.16750983,
#        180.31284919, 193.25786871, 189.97584424, 184.31278085,
#        183.43131817, 181.32171049, 175.37596609, 186.7879716 ,
#        188.34937138, 180.95749771, 190.8222188 , 182.23700761,
#        184.06296832, 185.02638139, 181.39905358, 187.19435336,
# ...

# %%
X
# Out:
# array([[  0,   3,   3, 183,   0, 187],
#        [  2,   2,   4, 200,   1, 184],
#        [  3,   3,   1, 198,   1, 243],
#        ...,
#        [  0,   1,   3, 156,   1, 253],
#        [  3,   2,   2, 246,   1, 233],
#        [  3,   2,   1, 108,   0, 198]], dtype=int64)
